# %% [markdown]
# # Data

# %%
import ipywidgets as widgets
from IPython.display import display
from src.title_abstract_screening import form
form()
# Out:
# HBox(children=(IntText(value=0, description='ID', layout=Layout(width='20%')), IntSlider(value=1, layout=Layou…
# HTML(value='', description='study ', layout=Layout(width='50%'))
# HTML(value='', description='subgroup', layout=Layout(width='50%'))
# HTML(value='', description='author(s) ', layout=Layout(width='90%'))
# HTML(value='', description='title ', layout=Layout(width='90%'))
# HTML(value='OBJECTIVE: Based on cross-education theory, this study aimed to investigate whether Healthy-Side L…
# HTML(value='2026', description='year ', layout=Layout(width='90%'))
# HTML(value='Journal of orthopaedic surgery and research', description='journal ', layout=Layout(width='90%'))
# HTML(value='embase', description='source', layout=Layout(width='50%'))
# HTML(value='10.1186/s13018-026-06776-6', description='DOI ', layout=Layout(width='90%'))
# HTML(value='https://doi.org/10.1186/s13018-026-06776-6', description='URL ', layout=Layout(width='90%'))

# %%
  
    yes = widgets.Button(
        value = "Yes", 
        description = "Yes", 
        icon = "check", 
        button_style = "success", 
        layout = {
            "width":"100%"})
    
    maybe = widgets.Button(
        value = "Maybe", 
        description = "Maybe", 
        icon = "", 
        button_style = "warning")
    
    no = widgets.Button(
        value = "No", 
        description = "No", 
        icon = "times", 
        button_style = "danger")
    
    save = widgets.Button(
        value = "Save", 
        description = "Save", 
        icon = "floppy-o", 
        button_style = "info")
    
    out = widgets.Output()
    
    buttons = widgets.HBox([yes, maybe, no, save])
    display(buttons, out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 yes = widgets.Button(
#       2     value = "Yes",
#       3     description = "Yes",
#       4     icon = "check",
#
# NameError: name 'widgets' is not defined

# %%
from src.ti
