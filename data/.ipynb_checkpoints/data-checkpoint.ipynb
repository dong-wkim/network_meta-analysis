# %% [markdown]
# ## Index
#
# - [patellar](G:\My%20Drive\network_meta-analysis\data/patellar/patellar.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/cochrane/cochrane.md)
# 	- [systematic_reviews](G:\My%20Drive\network_meta-analysis\data/patellar/systematic_reviews/systematic_reviews.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/patellar/systematic_reviews/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/patellar/systematic_reviews/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/patellar/systematic_reviews/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/patellar/systematic_reviews/cochrane/cochrane.md)
# - [hamstring](G:\My%20Drive\network_meta-analysis\data/hamstring/hamstring.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/hamstring/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/hamstring/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/hamstring/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/hamstring/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/hamstring/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/hamstring/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/hamstring/observational_studies/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/hamstring/observational_studies/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/hamstring/observational_studies/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/hamstring/observational_studies/cochrane/cochrane.md)
# 	- [systematic_reviews](G:\My%20Drive\network_meta-analysis\data/hamstring/systematic_reviews/systematic_reviews.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/hamstring/systematic_reviews/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/hamstring/systematic_reviews/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/hamstring/systematic_reviews/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/hamstring/systematic_reviews/cochrane/cochrane.md)
# - [quadriceps](G:\My%20Drive\network_meta-analysis\data/quadriceps/quadriceps.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/quadriceps/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/quadriceps/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/quadriceps/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/quadriceps/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/quadriceps/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/quadriceps/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/quadriceps/observational_studies/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/quadriceps/observational_studies/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/quadriceps/observational_studies/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/quadriceps/observational_studies/cochrane/cochrane.md)
# 	- [systematic_reviews](G:\My%20Drive\network_meta-analysis\data/quadriceps/systematic_reviews/systematic_reviews.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/quadriceps/systematic_reviews/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/quadriceps/systematic_reviews/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/quadriceps/systematic_reviews/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/quadriceps/systematic_reviews/cochrane/cochrane.md)
# - [peroneus](G:\My%20Drive\network_meta-analysis\data/peroneus/peroneus.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/peroneus/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/peroneus/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/peroneus/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/peroneus/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/peroneus/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/peroneus/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/peroneus/observational_studies/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/peroneus/observational_studies/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/peroneus/observational_studies/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/peroneus/observational_studies/cochrane/cochrane.md)
# 	- [systematic_reviews](G:\My%20Drive\network_meta-analysis\data/peroneus/systematic_reviews/systematic_reviews.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/peroneus/systematic_reviews/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/peroneus/systematic_reviews/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/peroneus/systematic_reviews/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/peroneus/systematic_reviews/cochrane/cochrane.md)
# - [achilles](G:\My%20Drive\network_meta-analysis\data/achilles/achilles.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/achilles/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/achilles/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/achilles/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/achilles/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/achilles/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/achilles/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/achilles/observational_studies/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/achilles/observational_studies/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/achilles/observational_studies/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/achilles/observational_studies/cochrane/cochrane.md)
# 	- [systematic_reviews](G:\My%20Drive\network_meta-analysis\data/achilles/systematic_reviews/systematic_reviews.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/achilles/systematic_reviews/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/achilles/systematic_reviews/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/achilles/systematic_reviews/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/achilles/systematic_reviews/cochrane/cochrane.md)
# - [tibialis](G:\My%20Drive\network_meta-analysis\data/tibialis/tibialis.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/tibialis/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/tibialis/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/tibialis/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/tibialis/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/tibialis/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/tibialis/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/tibialis/observational_studies/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/tibialis/observational_studies/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/tibialis/observational_studies/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/tibialis/observational_studies/cochrane/cochrane.md)
# 	- [systematic_reviews](G:\My%20Drive\network_meta-analysis\data/tibialis/systematic_reviews/systematic_reviews.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/tibialis/systematic_reviews/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/tibialis/systematic_reviews/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/tibialis/systematic_reviews/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/tibialis/systematic_reviews/cochrane/cochrane.md)

# %% [markdown]
# Create the structure above using `os.makedirs`.

# %%
# template for automated directory structure creation (replace key:value dictionary lists with folder names)
import os
from pathlib import Path

# level 1 key:value pairs
subgroups = {
    'pm' : 'patellar', 
    'ht' : 'hamstring', 
    'qt' : 'quadriceps', 
    'plt': 'peroneus', 
    'at' : 'achilles', 
    'ta' : 'tibialis'
}

# level 2 key:value pairs
study_designs = {
    'rct': 'randomized_controlled_trials', 
    'obs': 'observational_studies', 
    'reviews': 'systematic_reviews'
}

# level 3 key:value pairs
sources = {
    'pm': 'pubmed',
    'em': 'embase', 
    'wos': 'wos', 
    'co': 'cochrane'
}

folder = f"./{x}/{y}/{z}"
filename = f"{a}_{b}_{c}"
file = f"{folder}/{filename}.md"
root = os.getcwd()
root = root.replace("My Drive", "My%20Drive")
path = Path(root, folder, file)

for a, x in subgroups.items():
    print(f"- [{x}]({root}/{x}/{x}.md)")
    for b, y in study_designs.items():
        print(f"\t- [{y}]({root}/{x}/{y}/{y}.md)")
        for c, z in sources.items():
            folder = f"./{x}/{y}/{z}"
            filename = f"{a}_{b}_{c}"
            file = f"{folder}/{filename}.md"
            root = os.getcwd()
            root = root.replace("My Drive", "My%20Drive")
            path = Path(root, folder, file)
            os.makedirs(folder, exist_ok = True)
            print(f"\t\t- [{z}]({root}/{x}/{y}/{z}/{z}.md)")
            #markdown = f"\t\t- [{filename}]({path})"
            #print(markdown)
            with open(f"./index.md", "w") as f:
                f.write(markdown)
# Out:
# - [patellar](G:\My%20Drive\network_meta-analysis\data/patellar/patellar.md)
# 	- [randomized_controlled_trials](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/randomized_controlled_trials.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/pubmed/pubmed.md)
# 		- [embase](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/embase/embase.md)
# 		- [wos](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/wos/wos.md)
# 		- [cochrane](G:\My%20Drive\network_meta-analysis\data/patellar/randomized_controlled_trials/cochrane/cochrane.md)
# 	- [observational_studies](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/observational_studies.md)
# 		- [pubmed](G:\My%20Drive\network_meta-analysis\data/patellar/observational_studies/pubmed/pubmed.md)
# ...
