# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ## Layout Template

# %%
from ipywidgets import AppLayout, Button, Layout

def create_expanded_button(description, button_style):
    return Button(description=description, button_style=button_style, layout=Layout(height='auto', width='auto'))

header_button = create_expanded_button('Header', 'success')
left_button = create_expanded_button('Left', 'info')
center_button = create_expanded_button('Center', 'warning')
right_button = create_expanded_button('Right', 'info')
footer_button = create_expanded_button('Footer', 'success')

AppLayout(header=header_button,
          left_sidebar=left_button,
          center=center_button,
          right_sidebar=right_button,
          footer=footer_button)
# Out:
# AppLayout(children=(Button(button_style='success', description='Header', layout=Layout(grid_area='header', hei…

# %%
a = widgets.IntSlider()
b = widgets.FloatSlider()
c = widgets.FloatLogSlider()
#d = widgets.FloatLogitSlider()
e = widgets.IntRangeSlider()
f = widgets.FloatRangeSlider()
g = widgets.IntProgress()
h = widgets.FloatProgress()
i = widgets.BoundedIntText()
j = widgets.BoundedFloatText()
k = widgets.IntText()
l = widgets.FloatText()
m = widgets.ToggleButton()
n = widgets.Checkbox()
o = widgets.Valid()
p = widgets.Dropdown()
q = widgets.RadioButtons()
r = widgets.Select()
s = widgets.SelectionSlider(options = ["BPTB", "HT", "QT", "PLT", "AT", "TA"], value = "BPTB")
t = widgets.SelectionRangeSlider(options = ["BPTB", "HT", "QT", "PLT", "AT", "TA"], value = ["BPTB", "HT"])
u = widgets.ToggleButtons(options = ["BPTB", "HT", "QT", "PLT", "AT", "TA"], value = "BPTB")
v = widgets.SelectMultiple(options = ["BPTB", "HT", "QT", "PLT", "AT", "TA"], value = ["BPTB", "HT"])


display(a)
display(b)
display(c)
# display(d)
display(e)
display(f)
display(g)
display(h)
display(i)
display(j)
display(k)
display(l)
display(m) # toggle button 
display(n) # checkbox 
display(o) # valid 
display(p) # dropdown
display(q) # radiobuttons
display(r) 
display(s)
display(t)
display(u)
display(v)
# Out:
# IntSlider(value=0)
# FloatSlider(value=0.0)
# FloatLogSlider(value=1.0)
# IntRangeSlider(value=(25, 75))
# FloatRangeSlider(value=(25.0, 75.0))
# IntProgress(value=0)
# FloatProgress(value=0.0)
# BoundedIntText(value=0)
# BoundedFloatText(value=0.0)
# IntText(value=0)
# FloatText(value=0.0)
# ToggleButton(value=False)
# Checkbox(value=False)
# Valid(value=False)
# Dropdown(options=(), value=None)
# RadioButtons(options=(), value=None)
# Select(options=(), value=None)
# SelectionSlider(options=('BPTB', 'HT', 'QT', 'PLT', 'AT', 'TA'), value='BPTB')
# SelectionRangeSlider(index=(0, 1), options=('BPTB', 'HT', 'QT', 'PLT', 'AT', 'TA'), value=('BPTB', 'HT'))
# ToggleButtons(options=('BPTB', 'HT', 'QT', 'PLT', 'AT', 'TA'), value='BPTB')
# SelectMultiple(index=(0, 1), options=('BPTB', 'HT', 'QT', 'PLT', 'AT', 'TA'), value=('BPTB', 'HT'))
