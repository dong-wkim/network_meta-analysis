# %% [markdown]
# <a id="forms"></a>
#
# <div align="center">
#     <h1 style="font-family:Times New Roman;font-variant: small-caps;">
#         Forms
#     </h1>
# </div>

# %% [markdown]
# **Reference Guide**
#
# After making notes and reading a lot about widgets, which are essentially components that together make up web applications, they allow the user to interact with the back-end logic of the application, and thus, is in my opinion, crucial for developing any sort of useful things that people will use.
#
# I think firstly, code is most important, but after the prototype is written, the organization of components seem to facilitate further ideas to develop and for revisions to take place, as the organization allows presentation, and with that I found myself more able to get in the mind of someone who may potentially use it.

# %% [markdown]
# **Organization of components**

# %% [markdown]
# Layouts

# %%
# !pip install polar
# Out:
# Collecting polar
#   Downloading polar-0.0.127.tar.gz (11 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas in C:\tools\.venv\Lib\site-packages (from polar) (2.3.3)
# Requirement already satisfied: numpy in C:\tools\.venv\Lib\site-packages (from polar) (2.4.4)
# Collecting scipy (from polar)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting statsmodels (from polar)
#   Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting scikit-learn (from polar)
#   Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: seaborn in C:\tools\.venv\Lib\site-packages (from polar) (0.13.2)
# Collecting cryptography (from polar)
#   Downloading cryptography-47.0.0-cp311-abi3-win_amd64.whl.metadata (4.5 kB)
# Collecting nltk (from polar)
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting python-pptx (from polar)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting imblearn (from polar)
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: cffi>=2.0.0 in C:\tools\.venv\Lib\site-packages (from cryptography->polar) (2.0.0)
# Requirement already satisfied: pycparser in C:\tools\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography->polar) (3.0)
# Collecting imbalanced-learn (from imblearn->polar)
#   Downloading imbalanced_learn-0.14.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting sklearn-compat<0.2,>=0.1.5 (from imbalanced-learn->imblearn->polar)
#   Downloading sklearn_compat-0.1.5-py3-none-any.whl.metadata (20 kB)
# Collecting joblib<2,>=1.2.0 (from imbalanced-learn->imblearn->polar)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl<4,>=2.0.0 (from imbalanced-learn->imblearn->polar)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click in C:\tools\.venv\Lib\site-packages (from nltk->polar) (8.1.7)
# Collecting regex>=2021.8.3 (from nltk->polar)
#   Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk->polar)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in C:\tools\.venv\Lib\site-packages (from click->nltk->polar) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\tools\.venv\Lib\site-packages (from pandas->polar) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\tools\.venv\Lib\site-packages (from pandas->polar) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\tools\.venv\Lib\site-packages (from pandas->polar) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\tools\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas->polar) (1.17.0)
# Requirement already satisfied: Pillow>=3.3.2 in C:\tools\.venv\Lib\site-packages (from python-pptx->polar) (12.2.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx->polar)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: lxml>=3.1.0 in C:\tools\.venv\Lib\site-packages (from python-pptx->polar) (6.1.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in C:\tools\.venv\Lib\site-packages (from python-pptx->polar) (4.15.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\tools\.venv\Lib\site-packages (from seaborn->polar) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\tools\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->polar) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\tools\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->polar) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\tools\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->polar) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\tools\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->polar) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\tools\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->polar) (26.2)
# Requirement already satisfied: pyparsing>=3 in C:\tools\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->polar) (3.3.2)
# Collecting patsy>=0.5.6 (from statsmodels->polar)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Downloading cryptography-47.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------------- -------------------- 1.8/3.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 9.9 MB/s  0:00:00
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.6/8.0 MB 12.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 11.2 MB/s  0:00:00
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.1/36.5 MB 14.4 MB/s eta 0:00:03
#    ------ --------------------------------- 5.5/36.5 MB 13.2 MB/s eta 0:00:03
#    --------- ------------------------------ 8.4/36.5 MB 13.0 MB/s eta 0:00:03
#    ------------ --------------------------- 11.0/36.5 MB 12.7 MB/s eta 0:00:03
#    -------------- ------------------------- 13.6/36.5 MB 12.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.0/36.5 MB 12.5 MB/s eta 0:00:02
#    -------------------- ------------------- 18.6/36.5 MB 12.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 21.2/36.5 MB 12.5 MB/s eta 0:00:02
#    -------------------------- ------------- 23.9/36.5 MB 12.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 26.5/36.5 MB 12.4 MB/s eta 0:00:01
#    ------------------------------- -------- 28.8/36.5 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.5/36.5 MB 12.3 MB/s eta 0:00:01
#    ------------------------------------- -- 34.1/36.5 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 11.8 MB/s  0:00:03
# Downloading sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 13.4 MB/s  0:00:00
# Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl (277 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/9.5 MB 12.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.5 MB 12.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.5 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 11.5 MB/s  0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Building wheels for collected packages: polar
#   Building wheel for polar (pyproject.toml): started
#   Building wheel for polar (pyproject.toml): finished with status 'done'
#   Created wheel for polar: filename=polar-0.0.127-py3-none-any.whl size=10113 sha256=6f26385b1553bc8bf93b4192b20d66240748c6539a543e664211f522462c3a0b
#   Stored in directory: c:\users\danny\appdata\local\pip\cache\wheels\f9\1a\4e\759efbc4993423b3bb8c25d3156a2283a9d3022776dbe5123b
# Successfully built polar
# Installing collected packages: XlsxWriter, tqdm, threadpoolctl, scipy, regex, patsy, joblib, scikit-learn, python-pptx, nltk, cryptography, statsmodels, sklearn-compat, imbalanced-learn, imblearn, polar
#
#    ----------------------------------------  0/16 [XlsxWriter]
#    ----------------------------------------  0/16 [XlsxWriter]
#    ----------------------------------------  0/16 [XlsxWriter]
#    ----------------------------------------  0/16 [XlsxWriter]
#    ----------------------------------------  0/16 [XlsxWriter]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
#    -- -------------------------------------  1/16 [tqdm]
#    ----- ----------------------------------  2/16 [threadpoolctl]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ------- --------------------------------  3/16 [scipy]
#    ---------- -----------------------------  4/16 [regex]
#    ---------- -----------------------------  4/16 [regex]
#    ------------ ---------------------------  5/16 [patsy]
#    ------------ ---------------------------  5/16 [patsy]
#    ------------ ---------------------------  5/16 [patsy]
#    ------------ ---------------------------  5/16 [patsy]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    --------------- ------------------------  6/16 [joblib]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    ----------------- ----------------------  7/16 [scikit-learn]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    -------------------- -------------------  8/16 [python-pptx]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ---------------------- -----------------  9/16 [nltk]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    ------------------------- -------------- 10/16 [cryptography]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    --------------------------- ------------ 11/16 [statsmodels]
#    ------------------------------ --------- 12/16 [sklearn-compat]
#    ------------------------------ --------- 12/16 [sklearn-compat]
#    ------------------------------ --------- 12/16 [sklearn-compat]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    -------------------------------- ------- 13/16 [imbalanced-learn]
#    ------------------------------------- -- 15/16 [polar]
#    ---------------------------------------- 16/16 [polar]
#
# Successfully installed XlsxWriter-3.2.9 cryptography-47.0.0 imbalanced-learn-0.14.1 imblearn-0.0 joblib-1.5.3 nltk-3.9.4 patsy-1.0.2 polar-0.0.127 python-pptx-1.0.2 regex-2026.4.4 scikit-learn-1.8.0 scipy-1.17.1 sklearn-compat-0.1.5 statsmodels-0.14.6 threadpoolctl-3.6.0 tqdm-4.67.3
# WARNING: Ignoring invalid distribution ~otebook (C:\tools\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\tools\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\tools\.venv\Lib\site-packages)

# %% [markdown]
# The design and creation of the database, adapted towards universality while maintaining effective applicability to the current projects' needs were faced with the following challenges, and proposed solutions follow:
#
# | Problem | Solution |
# | :------ | :------- |
# | 1. **Network meta-analysis** data vs. single-arm meta-analysis data. Studies with more than one relevant subgroup, as in comparative studies of two or more study arms, prompted a data collection design which would facilitate the inclusion of the studies twice  without compromising data integrity due to data duplicity.    |  1. The proposed solution was to divide the study results into two separate dataframes, one at arm-level and the other at contrast-level. The implication this has is that the same data will be entered twice, once per sheet. This was seen to be an acceptable trade-off, in comparison to potential errors due to complexity.   |
# | 2. Continuous vs. dichotomous data types. In order to avoid the plethora of dataframes resulting from the differences in data structures when designing template data entry tables and forms, it was considered, with ample detail, the pros and cons of dividing the data by outcomes, and data types, which is a common method of data collection. Due to the complexity of the data that is reported in literature, simplifying the data recording instruments, such as the dataframes, beyond the level of simplicity of the data that was to be recorded was deemed unwise.       | The tables were broken down into smaller manageable subtables for data entry.         |
# | 3.         |          |
# | 4.         |          |

# %%
import pandas as pd
studies = pd.DataFrame(
    index = range(1, len(df)+1),
    columns = ['id', 'study']) # PK no duplicates
subgroups = pd.DataFrame(columns = ['id', 'subgroup(s)']) # PK = FK duplicates okay
outcomes = pd.DataFrame(columns = ['id', 'outcome(s)'])
arms = pd.DataFrame(columns = ['id', 'arm(s)'])  

df = pd.concat([studies, subgroups, outcomes, arms]).fillna("") # study information
df.index = df['id']
temp = pd.DataFrame(columns = ['id', 'ni', 'xi', 'yi', 'sdi', 'sei', 'vi', 'a', 'b', 'q1', 'm', 'q3'])
temp.head()

df.head()
# Out:
#    id study subgroup(s) outcome(s) arm(s)
# id

# %%
import ipywidgets as widgets
from IPython.display import display
from src.forms import forms


a = widgets.BoundedIntText()
b = widgets.Text()
c = widgets.Text()
d = widgets.Text()

a.min = 1
a.max = 604
a.description = "ID"
a.layout = {"width":"25%"}

items = [a, b, c, d]

P1 = widgets.Box(items)




# -------------------------- PAGE 2 ---------------------------------#

items = [widgets.Label(str(i)) for i in range(4)]
P2 = widgets.HBox(items)


# ------------------------------ PAGE 3 -----------------------------#

items = [widgets.Label(str(i)) for i in range(4)]
left_box = widgets.VBox([items[0], items[1]])
right_box = widgets.VBox([items[2], items[3]])
P3 = widgets.HBox([left_box, right_box])


# --------------------------- PAGE 4 --------------------------------#

items = [widgets.Label(str(i)) for i in range(8)]
P4 = widgets.GridBox(items, layout=widgets.Layout(grid_template_columns="repeat(3, 100px)"))
P5 = widgets

# -----------------------------------------------------------#
titles = [] # set the tabbed page titles
children = [P1, P2]
tab = widgets.Tab(
    children = children,
    titles = titles)
#print("\n".join(tab.keys))
display(tab)
# Out:
# Tab(children=(Box(children=(BoundedIntText(value=1, description='ID', layout=Layout(width='25%'), max=604, min…

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, Javascript

# %%
reports = pd.read_csv("https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/31a9070ff303d8df83f2ad164b4331f8465a7e6d/systematic_review/screening/pdf/pdf.csv", encoding = "utf-8")
reports.head()
reports["id"] = range(1, len(reports)+1)

df = pd.DataFrame(columns = ["id", "study", "study_design", "level_evidence", "subgroup(s)", "outcome(s)", "arm(s)"])
df["id"] = reports["id"]
df["study"] = reports["study"]
df = df.fillna("")
df.head()
# Out:
#    id                study study_design level_evidence subgroup(s) outcome(s)  \
# 0   1  Martorell-de (2025)
# 1   2     Obradović (2023)
# 2   3    Iliopoulos (2017)
# 3   4       Valentí (2014)
# 4   5      Kautzner (2015)
#
#   arm(s)
# 0
# 1
# 2
# 3
# 4

# %%
from src.forms import forms
forms()
# Out:
# BoundedIntText(value=0, description='ID', layout=Layout(width='50%'))
# HTML(value='', description='study')
# Dropdown(description='study design', layout=Layout(width='50%'), options=('', 'Randomized controlled trial', '…
# SelectMultiple(description='subgroup(s)', index=(0,), layout=Layout(width='50%'), options=('BPTB', 'HT', 'QT',…
# Dropdown(description='arm(s)', options=('', 'single-arm', 'two-arm', 'multi-arm'), value='')
# SelectMultiple(description='outcome(s)', index=(0,), options=('', 'IKDC subjective', 'Lysholm', 'Tegner', 'Ins…
# Button(button_style='info', description='Save', icon='save', style=ButtonStyle())
# Output()

# %%
widgets.Button().keys

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd
import re
layout = widgets.Layout()
keys = layout.keys
list = "\n".join(keys)
list = re.sub(r"_(.*?)", "", list)
print(list)

# %%
columns = ["study", "study_design", "level_evidence", "subgroup(s)", "arm(s)", "outcome(s)"]

for x in columns:
    if x not in df.columns:
        df[x] = ""

df = df.fillna("")

a = widgets.BoundedIntText(
    value=int(df["id"].min()),
    min=int(df["id"].min()),
    max=int(df["id"].max()),
    description="ID",
    layout={"width": "30%"}
)

b = widgets.Text(
    description="study",
    value="",
    layout = {"width":"60%"})


l = widgets.Combobox(
    description="study design",
    options=[
        "",
        "randomized controlled trial",
        "non-randomized controlled trial",
        "prospective cohort study",
        "retrospective cohort study",
        "case-control study",
        "longitudinal study",
        "cross-sectional study",
        "case series",
        "case report",
        "review"
    ],
    value=""
)

p = widgets.Dropdown(
    description = "level evidence",
    options = ["", "I", "II", "III", "IV", "V"], value = "")

m = widgets.SelectMultiple(
    description="subgroup",
    options=["BPTB", "HT", "QT", "PLT", "AT", "TA"],
    value=(),
    layout={"width": "50%"}
)

n = widgets.Dropdown(
    description="arm(s)",
    options=["", "single-arm", "two-arm", "multi-arm"],
    value=""
)

o = widgets.SelectMultiple(
    description="outcome(s)",
    options=[
        "IKDC",
        "Lysholm",
        "Tegner",
        "Instrumental laxity",
        "Pivot shift",
        "Lachman",
        "Graft failure"
    ],
    value=(),
    layout={"width": "50%"}
)

save = widgets.Button(description = "Save", button_style = "info", icon = "save")
out = widgets.Output()

state = {}
loading = False

def remember_values():
    state[a.value] = {
        "study": b.value,
        "study_design": l.value,
        "subgroup(s)": m.value,
        "arm(s)": n.value,
        "outcome(s)": o.value,
        "level_evidence": p.value
    }

def update_study(change=None):
    row_id = a.value
    row = df.loc[df["id"] == row_id]

    if row.empty:
        b.value = ""
        l.value = ""
        m.value = ()
        n.value = ""
        o.value = ()
        return

    row = row.iloc[0]

    if row_id in state:
        b.value = state[row_id]["study"]
        l.value = state[row_id]["study_design"]
        m.value = state[row_id]["subgroup(s)"]
        n.value = state[row_id]["arm(s)"]
        o.value = state[row_id]["outcome(s)"]

    else:
        b.value = "" if pd.isna(row["study"]) else str(row["study"])
        l.value = "" if pd.isna(row["study_design"]) else str(row["study_design"])
        n.value = "" if pd.isna(row["arm(s)"]) else str(row["arm(s)"])

        subgroups = "" if pd.isna(row["subgroup(s)"]) else str(row["subgroup(s)"])
        outcomes = "" if pd.isna(row["outcome(s)"]) else str(row["outcome(s)"])

        m.value = tuple(x.strip() for x in subgroups.split(",") if x.strip())
        o.value = tuple(x.strip() for x in outcomes.split(",") if x.strip())


def save_values(change):
    row_id = a.value

    remember_values()

    df.loc[df["id"] == row_id, "study"] = b.value
    df.loc[df["id"] == row_id, "study_design"] = l.value
    df.loc[df["id"] == row_id, "subgroup(s)"] = ", ".join(m.value)
    df.loc[df["id"] == row_id, "arm(s)"] = n.value
    df.loc[df["id"] == row_id, "outcome(s)"] = ", ".join(o.value)
    df.loc[df["id"] == row_id, "level_evidence"] = p.value
    
    with out:
        out.clear_output()
        print(f"Saved values for ID {row_id}")

def remember_on_change(change):
    remember_values()

    l.observe(remember_on_change, names="value")
    m.observe(remember_on_change, names="value")
    n.observe(remember_on_change, names="value")
    o.observe(remember_on_change, names="value")
    
    a.observe(update_study, names="value")
    save.on_click(save_values)

# load first ID
update_study()

display(
    a,
    b,
    l,
    p,
    m,
    n,
    o,
    save,
    out
)

df.to_csv("./data_collection.csv", encoding = "utf-8")
# Out:
# BoundedIntText(value=1, description='ID', layout=Layout(width='30%'), max=603, min=1)
# Text(value='Martorell-de (2025)', description='study', layout=Layout(width='60%'))
# Combobox(value='', description='study design', options=('', 'randomized controlled trial', 'non-randomized con…
# Dropdown(description='level evidence', options=('', 'I', 'II', 'III', 'IV', 'V'), value='')
# SelectMultiple(description='subgroup', layout=Layout(width='50%'), options=('BPTB', 'HT', 'QT', 'PLT', 'AT', '…
# Dropdown(description='arm(s)', options=('', 'single-arm', 'two-arm', 'multi-arm'), value='')
# SelectMultiple(description='outcome(s)', layout=Layout(width='50%'), options=('IKDC', 'Lysholm', 'Tegner', 'In…
# Button(button_style='info', description='Save', icon='save', style=ButtonStyle())
# Output()

# %%
a = widgets.BoundedIntText(
    value=int(df["id"].min()),
    min=int(df["id"].min()),
    max=int(df["id"].max()),
    description="ID",
    layout={"width": "30%"}
)

b = widgets.Text(
    description="study",
    value="",
    layout={"width": "70%"}
)

l = widgets.Dropdown(
    description="study design",
    options=[
        "",
        "Randomized controlled trial",
        "Non-randomized controlled trial",
        "Prospective cohort study",
        "Retrospective cohort study",
        "Case-control study",
        "Longitudinal study",
        "Cross-sectional study",
        "Case series",
        "Case report",
        "Review"
    ],
    value=""
)

m = widgets.SelectMultiple(
    description="subgroup",
    options=["BPTB", "HT", "QT", "PLT", "AT", "TA"],
    value=(),
    layout={"width": "50%"}
)

n = widgets.Dropdown(
    description="arm(s)",
    options=["", "Single-arm", "Two-arm", "Multi-arm"],
    value=""
)

o = widgets.SelectMultiple(
    description="outcome(s)",
    options=[
        "IKDC",
        "Lysholm",
        "Tegner",
        "Instrumental laxity",
        "Pivot shift",
        "Lachman",
        "Graft failure"
    ],
    value=(),
    layout={"width": "50%"}
)

p = widgets.Dropdown(
    description="level evidence",
    options=["", "I", "II", "III", "IV", "V"],
    value=""
)

save = widgets.Button(description="Save", button_style="info")
out = widgets.Output()
# Out:
#   Cell In[56], line 97
#     row_id = a.value
#     ^
# IndentationError: expected an indented block after function definition on line 96

# %%
df.head(3)
# Out:
#    id                study study_design level_evidence subgroup(s) outcome(s)  \
# 0   1  Martorell-de (2025)
# 1   2     Obradović (2023)
# 2   3    Iliopoulos (2017)
#
#   arm(s)
# 0
# 1
# 2

# %%
import ipywidgets as widgets
from IPython.display import display, HTML, Javascript
import pandas as pd


reports = pd.read_csv("https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/31a9070ff303d8df83f2ad164b4331f8465a7e6d/systematic_review/screening/pdf/pdf.csv", encoding = "utf-8")
reports.head()
reports["id"] = range(1, len(reports)+1)

df = pd.DataFrame(columns = ["id", "study", "study_design", "level_evidence", "subgroup(s)", "outcome(s)", "arm(s)"])
df["id"] = reports["id"]
df["study"] = reports["study"]
df = df.fillna("")

a = widgets.BoundedIntText(description = "ID", layout = {"width":"50%"})
b = widgets.HTML(description = "study", value = "")
l = widgets.Dropdown(description = "study design", options = ["",
    "Randomized controlled trial", 
    "Non-randomized controlled trial",
    "Prospective cohort study",
    "Retrospective cohort study",
    "Case-control study",
    "Longitudinal study",
    "Cross-sectional study",
    "Case series",
    "Case report",
    "Review"], value = "",layout = {"width":"90%"})

m = widgets.SelectMultiple(options = [
    'BPTB', 
    'HT', 
    'QT', 
    'PLT', 
    'AT', 
    'TA'], value = ["BPTB"], description = "subgroup(s)", layout = {"width": "90%"})


n = widgets.Dropdown(options = [
    '',
    'single-arm',
    'two-arm',
    'multi-arm'], value = "", description = "arm(s)")

o = widgets.SelectMultiple(options = [
    '',
    'IKDC subjective',
    'Lysholm',
    'Tegner',
    'Instrumental laxity',
    'Pivot shift',
    'Lachman',
    'Graft rupture'
], value = ("",), description = "outcome(s)", layout = {"width": "90%"})
                           

save = widgets.Button(description="Save", button_style="info", icon = "save")
out = widgets.Output()


def save_values(change):    
    df.loc[df["id"] == a.value, "study"] = b.value
    df.loc[df["id"] == a.value, "study_design"] = l.value
    df.loc[df["id"] == a.value, "subgroup(s)"] = ", ".join(m.value)
    df.loc[df["id"] == a.value, "arm(s)"] = n.value
    df.loc[df["id"] == a.value, "outcome(s)"] = ", ".join(o.value)
    df.loc[df["id"] == a.value, "level_evidence"] = p.value

    with out:
        out.clear_output()
        print(f"Saved values for ID {a.value}")


def update_study(change):
    df.loc[df["id"] == a.value]

    if a.value >0:
        b.value = str(row["study"].iloc[0])
    else:
        b.value = ""

l.observe(update_study, names="value")
m.observe(update_study, names="value")
n.observe(update_study, names="value")
o.observe(update_study, names="value")

save.on_click(save_values)

w = widgets.VBox([a, b, l, p, m, n, o, save, out])
display(w)
# Out:
# VBox(children=(BoundedIntText(value=0, description='ID', layout=Layout(width='50%')), HTML(value='', descripti…
