# %% [markdown]
# <a id="title_abstract_screening"></a>
#
# <h2 align="center" style="font-family:Times New Roman;font-variant:small-caps;">
#     Title abstract screening
# </h2>

# %%
from title_abstract_screening import title_abstract_screening
title_abstract_screening()
# Out:
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# Stack(children=(IntText(value=0, description='ID ', layout=Layout(width='100%')), Textarea(value='', descripti…
# HBox(children=(Button(description='Yes', style=ButtonStyle(button_color='#A5D46A')), Button(description='Maybe…
# Output()
