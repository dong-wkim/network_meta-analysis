# %% [markdown]
# <a id="data-collection"></a>
#
# <h1 align="center" style="font-family:Times New Roman;font-variant:small-caps;">Data Collection</h1>

# %% [markdown]
# <a id="database"></a>
# <div align="center">
# <h2 style="font-family:Times New Roman;font-variant: small-caps;">Database</h2></div>
#
# Database Design and Management

# %%
from IPython.display import display, Javascript
import ipywidgets as widgets


", ".join(widgets.Textarea().keys)

def text_area():
    w = widgets.Textarea() # continuous_update, description, description_allow_html, disabled, layout, placeholder, rows, style, tabbable, tooltip, value
    out = widgets.Output()
    display(w, out)

display(widgets.Textarea(), widgets.Output())
display(widgets.Textarea(), widgets.Output())
display(widgets.Textarea(), widgets.Output())
display(widgets.Textarea(), widgets.Output())
display(widgets.Textarea(), widgets.Output())
display(widgets.Textarea(), widgets.Output())

# for each study **arm**, which are subgroups: 

# data type (str, Dropdown)
# outcome(s) (str, SelectMultiple)
# ni (sample size)
# xi (raw effect size recorded from data collection)
# yi (scaled, transformed and standardized effect size ready for analysis)
# sei 

ai, bi, ci, di, n1i, n2i, x1i, x2i, t1i, t2i,
       m1i, m2i, sd1i, sd2i, xi, mi, ri, ti, sdi, r2i, ni, yi, vi, sei,

data_type = ['continuous', 'dichotomous'] 

outcome_measures = {
    "IKDC-SKF": ikdc_subjective,
    "Lysholm": lysholm,
    "Tegner": tegner,
    "Instrumental laxity": instrumental_laxity,
    "Pivot shift": pivot_shift,
    "Lachman": lachman,
    "Graft rupture": graft_rupture
}

id = widgets.
study	
title	
study_design	
subgroup 
outcome
arm
# Out:
# Textarea(value='')
# Output()

# %%
import ipywidgets as widgets
print(widgets.Button.on_click.__doc__)

from IPython.display import display
button = widgets.Button(description = "Click Me")
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
    with output:
        print("Submitted")
        
button.on_click(on_button_clicked)
# Out:
# Register a callback to execute when the button is clicked.
#
# The callback will be called with one argument, the clicked button
# widget instance.
#
# Parameters
# ----------
# remove: bool (optional)
#     Set to true to remove the callback from the list of callbacks.
# Button(description='Click Me', style=ButtonStyle())
# Output()

# %% [markdown]
# - [x] match all existing and non-existing columns with appropriate forms component (ipywedgit)
# - [x] write out the python scripts to display them.
# - [ ] add widget keys as arguments to create custom widget functions
# - [ ] deploy the appropriate layouts, containers, and widgets as web application pages.
