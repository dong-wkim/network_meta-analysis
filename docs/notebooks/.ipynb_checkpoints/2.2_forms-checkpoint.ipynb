# %% [markdown]
# <a id="forms"></a>
#
# <div align="center">
#     <h1 style="font-family:Times New Roman;font-variant: small-caps;">
#         Forms
#     </h1>
# </div>

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, Javascript

# %%
reports = pd.read_csv("https://raw.githubusercontent.com/dong-wkim/network_meta-analysis/31a9070ff303d8df83f2ad164b4331f8465a7e6d/systematic_review/screening/pdf/pdf.csv", encoding = "utf-8")
reports.head()
reports["id"] = range(1, len(reports)+1)

# %%
df = pd.DataFrame(columns = ["id", "study", "study_design", "loe", "subgroup(s)", "outcome(s)", "arm(s)"])
df["id"] = reports["id"]
df["study"] = reports["study"]
df.fillna("")
# Out:
#       id                study study_design loe subgroup(s) outcome(s) arm(s)
# 0      1  Martorell-de (2025)
# 1      2     Obradović (2023)
# 2      3    Iliopoulos (2017)
# 3      4       Valentí (2014)
# 4      5      Kautzner (2015)
# ..   ...                  ...          ...  ..         ...        ...    ...
# 598  599         Lynch (2019)
# 599  600       Muhamad (2025)
# 600  601       Hegarty (2023)
# 601  602
# 602  603
#
# [603 rows x 7 columns]

# %%
df.head()
# Out:
#    id                study study_design  loe subgroup(s) outcome(s) arm(s)
# 0   1  Martorell-de (2025)          NaN  NaN         NaN        NaN    NaN
# 1   2     Obradović (2023)          NaN  NaN         NaN        NaN    NaN
# 2   3    Iliopoulos (2017)          NaN  NaN         NaN        NaN    NaN
# 3   4       Valentí (2014)          NaN  NaN         NaN        NaN    NaN
# 4   5      Kautzner (2015)          NaN  NaN         NaN        NaN    NaN

# %%
a = widgets.BoundedIntText(description = "ID", layout = {"width":"50%"})
b = widgets.HTML(description = "study", value = "")
l = widgets.Dropdown(description = "study design", options = ["",
    "Randomized controlled trial", 
    "Non-randomized controlled trial",
    "Prospective cohort study",
    "Retrospective cohort study",
    "Case-control study",
    "Longitudinal study",
    "Cross-sectional study",
    "Case series",
    "Case report",
    "Review"], value = "",layout = {"width":"50%"})

m = widgets.SelectMultiple(options = [
    'BPTB', 
    'HT', 
    'QT', 
    'PLT', 
    'AT', 
    'TA'], value = ["BPTB"], description = "subgroup(s)", layout = {"width": "50%"})

n = widgets.Dropdown(options = [
    '',
    'single-arm',
    'two-arm',
    'multi-arm'], value = "", description = "arm(s)")

o = widgets.SelectMultiple(options = [
    '',
    'IKDC subjective',
    'Lysholm',
    'Tegner',
    'Instrumental laxity',
    'Pivot shift',
    'Lachman',
    'Graft rupture'
], value = ("",))

# %%
save = widgets.Button(description="Save", button_style="info")
out = widgets.Output()

columns = ["study_design", "subgroup(s)", "outcome(s)", "arm(s)"]
for col in columns:
    if col not in df.columns:
        df[col] = ""

def save_values(change):
    row_id = a.value

    df.loc[df["id"] == row_id, "study"] = b.value
    df.loc[df["id"] == row_id, "study_design"] = l.value
    df.loc[df["id"] == row_id, "subgroup(s)"] = ", ".join(m.value)
    df.loc[df["id"] == row_id, "arm(s)"] = n.value
    df.loc[df["id"] == row_id, "outcome(s)"] = o.value

    with out:
        out.clear_output()
        print(f"Saved values for ID {row_id}")


display(
    a,
    b,
    l,
    m,
    n,
    o,
    save,
    out
)

def update_study(change):
    row = df.loc[df["id"] == a.value]

    if not row.empty:
        b.value = str(row["study"].iloc[0])
    else:
        b.value = ""

l.observe(update_study, names="value")
m.observe(update_study, names="value")
n.observe(update_study, names="value")
o.observe(update_study, names="value")

save.on_click(save_values)
# Out:
# BoundedIntText(value=3, description='ID', layout=Layout(width='20%'), max=603, min=1)
# HTML(value='Iliopoulos (2017)', description='study')
# Dropdown(description='study design', index=3, options=('', 'Randomized controlled trial', 'Non-randomized cont…
# SelectMultiple(description='subgroup', index=(2, 4, 5), layout=Layout(width='50%'), options=('BPTB', 'HT', 'QT…
# Dropdown(description='arm(s)', index=1, options=('', 'Single-arm', 'Two-arm', 'Multi-arm'), value='Single-arm'…
# SelectMultiple(description='outcome(s)', index=(0, 1, 3), layout=Layout(width='50%'), options=('IKDC', 'Lyshol…
# Button(button_style='info', description='Save', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display
import pandas as pd

# -------------------------
# make sure columns exist
# -------------------------

columns = ["study", "study_design", "subgroup(s)", "arm(s)", "outcome(s)"]

for col in columns:
    if col not in df.columns:
        df[col] = ""

# -------------------------
# widgets
# -------------------------

a = widgets.BoundedIntText(
    value=int(df["id"].min()),
    min=int(df["id"].min()),
    max=int(df["id"].max()),
    description="ID",
    layout={"width": "20%"}
)

b = widgets.HTML(
    description="study",
    value=""
)

l = widgets.Dropdown(
    description="study design",
    options=[
        "",
        "Randomized controlled trial",
        "Non-randomized controlled trial",
        "Prospective cohort study",
        "Retrospective cohort study",
        "Case-control study",
        "Longitudinal study",
        "Cross-sectional study",
        "Case series",
        "Case report",
        "Review"
    ],
    value=""
)

m = widgets.SelectMultiple(
    description="subgroup",
    options=["BPTB", "HT", "QT", "PLT", "AT", "TA"],
    value=(),
    layout={"width": "50%"}
)

n = widgets.Dropdown(
    description="arm(s)",
    options=["", "Single-arm", "Two-arm", "Multi-arm"],
    value=""
)

o = widgets.SelectMultiple(
    description="outcome(s)",
    options=[
        "IKDC",
        "Lysholm",
        "Tegner",
        "KT-1000/KT-2000",
        "Pivot shift",
        "Lachman",
        "Graft failure"
    ],
    value=(),
    layout={"width": "50%"}
)

p = widgets.Dropdown(
    description = "Level of evidence",
    options = ["", "I", "II", "III", "IV", "V"],
    value = "")
save = widgets.Button(description="Save", button_style="info")
out = widgets.Output()

# -------------------------
# temporary unsaved memory
# -------------------------

state = {}

def remember_values():
    state[a.value] = {
        "study": b.value,
        "study_design": l.value,
        "subgroup(s)": m.value,
        "arm(s)": n.value,
        "outcome(s)": o.value
    }

# -------------------------
# update widgets when ID changes
# -------------------------

def update_study(change=None):
    row_id = a.value
    row = df.loc[df["id"] == row_id]

    if row.empty:
        b.value = ""
        l.value = ""
        m.value = ()
        n.value = ""
        o.value = ()
        return

    row = row.iloc[0]

    if row_id in state:
        b.value = state[row_id]["study"]
        l.value = state[row_id]["study_design"]
        m.value = state[row_id]["subgroup(s)"]
        n.value = state[row_id]["arm(s)"]
        o.value = state[row_id]["outcome(s)"]

    else:
        b.value = "" if pd.isna(row["study"]) else str(row["study"])
        l.value = "" if pd.isna(row["study_design"]) else str(row["study_design"])
        n.value = "" if pd.isna(row["arm(s)"]) else str(row["arm(s)"])

        subgroups = "" if pd.isna(row["subgroup(s)"]) else str(row["subgroup(s)"])
        outcomes = "" if pd.isna(row["outcome(s)"]) else str(row["outcome(s)"])

        m.value = tuple(x.strip() for x in subgroups.split(",") if x.strip())
        o.value = tuple(x.strip() for x in outcomes.split(",") if x.strip())

# -------------------------
# save button
# -------------------------

def save_values(change):
    row_id = a.value

    remember_values()

    df.loc[df["id"] == row_id, "study"] = b.value
    df.loc[df["id"] == row_id, "study_design"] = l.value
    df.loc[df["id"] == row_id, "subgroup(s)"] = ", ".join(m.value)
    df.loc[df["id"] == row_id, "arm(s)"] = n.value
    df.loc[df["id"] == row_id, "outcome(s)"] = ", ".join(o.value)

    with out:
        out.clear_output()
        print(f"Saved values for ID {row_id}")

def remember_on_change(change):
    remember_values()

l.observe(remember_on_change, names="value")
m.observe(remember_on_change, names="value")
n.observe(remember_on_change, names="value")
o.observe(remember_on_change, names="value")

a.observe(update_study, names="value")
save.on_click(save_values)

# load first ID
update_study()

display(
    a,
    b,
    l,
    p,
    m,
    n,
    o,
    save,
    out
)

df.fillna("")
df.head(50)
df.to_csv("./data_collection.csv", encoding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8
#       9 columns = ["study", "study_design", "subgroup(s)", "arm(s)", "outcome(s)"]
#      10
#      11 for col in columns:
# ---> 12     if col not in df.columns:
#      13         df[col] = ""
#      14
#      15 # -------------------------
#
# NameError: name 'df' is not defined

# %%
df.head(50)
# Out:
#     id                study                     study_design  loe  \
# 0    1  Martorell-de (2025)       Retrospective cohort study  NaN
# 1    2     Obradović (2023)  Non-randomized controlled trial  NaN
# 2    3    Iliopoulos (2017)         Prospective cohort study  NaN
# 3    4       Valentí (2014)      Randomized controlled trial  NaN
# 4    5      Kautzner (2015)      Randomized controlled trial  NaN
# 5    6      Peterson (2014)                              NaN  NaN
# 6    7          Mayr (2014)                              NaN  NaN
# 7    8        Seijas (2013)       Retrospective cohort study  NaN
# 8    9    Indelicato (2013)                              NaN  NaN
# 9   10          Ward (2011)       Retrospective cohort study  NaN
# 10  11     Cervellin (2012)                              NaN  NaN
# 11  12       Drogset (2011)                              NaN  NaN
# 12  13         Volpi (2010)                              NaN  NaN
# 13  14    Zaffagnini (2011)                              NaN  NaN
# 14  15           Nin (2009)                              NaN  NaN
# 15  16           Sun (2009)                              NaN  NaN
# 16  17           Sun (2009)                              NaN  NaN
# 17  18         Dauri (2009)                              NaN  NaN
# 18  19           Sun (2009)                              NaN  NaN
# 19  20           Ito (2007)                              NaN  NaN
# 20  21        Isberg (2006)                              NaN  NaN
# 21  22    Harilainen (2006)                              NaN  NaN
# 22  23       Kaeding (2005)                              NaN  NaN
# 23  24      Nicholas (2004)                              NaN  NaN
# 24  25        Decker (2004)                              NaN  NaN
# 25  26        Alford (2003)                              NaN  NaN
# 26  27     Mikkelsen (2003)                              NaN  NaN
# 27  28         Straw (2003)                              NaN  NaN
# 28  29         Muren (2003)                              NaN  NaN
# 29  30        Otsuka (2003)                              NaN  NaN
# 30  31       Drogset (2002)                              NaN  NaN
# 31  32      Hoenecke (2002)                              NaN  NaN
# 32  33           Nau (2002)                              NaN  NaN
# 33  34       Yoshiya (2002)                              NaN  NaN
# 34  35          Hess (2002)                              NaN  NaN
# 35  36        Follak (2001)                              NaN  NaN
# 36  37       McCarty (2001)                              NaN  NaN
# 37  38       Webster (2001)                              NaN  NaN
# 38  39       Ejerhed (2001)                              NaN  NaN
# 39  40     Brandsson (2001)                              NaN  NaN
# 40  41          Fink (2000)                              NaN  NaN
# 41  42      Amendola (1999)                              NaN  NaN
# 42  43       McGuire (1999)                              NaN  NaN
# 43  44           van (1998)                              NaN  NaN
# 44  45          Popp (1998)                              NaN  NaN
# 45  46        Barber (1998)                              NaN  NaN
# 46  47       Tohyama (1998)                              NaN  NaN
# 47  48     Brandsson (1998)                              NaN  NaN
# 48  49        Gerich (1997)                              NaN  NaN
# 49  50     Thuresson (1996)                              NaN  NaN
#
#         subgroup(s)                            outcome(s)      arm(s)
# 0      BPTB, HT, QT  Tegner, KT-1000/KT-2000, Pivot shift   Multi-arm
# 1                        Lysholm, Tegner, KT-1000/KT-2000  Single-arm
# 2        QT, AT, TA        IKDC, Lysholm, KT-1000/KT-2000  Single-arm
# 3           PLT, AT        IKDC, Lysholm, KT-1000/KT-2000     Two-arm
# 4   QT, PLT, AT, TA  Tegner, KT-1000/KT-2000, Pivot shift     Two-arm
# 5               NaN                                   NaN         NaN
# 6               NaN                                   NaN         NaN
# 7                AT
# 8               NaN                                   NaN         NaN
# 9
# 10              NaN                                   NaN         NaN
# 11              NaN                                   NaN         NaN
# 12              NaN                                   NaN         NaN
# 13              NaN                                   NaN         NaN
# 14              NaN                                   NaN         NaN
# 15              NaN                                   NaN         NaN
# 16              NaN                                   NaN         NaN
# 17              NaN                                   NaN         NaN
# 18              NaN                                   NaN         NaN
# 19              NaN                                   NaN         NaN
# 20              NaN                                   NaN         NaN
# 21              NaN                                   NaN         NaN
# 22              NaN                                   NaN         NaN
# 23              NaN                                   NaN         NaN
# 24              NaN                                   NaN         NaN
# 25              NaN                                   NaN         NaN
# 26              NaN                                   NaN         NaN
# 27              NaN                                   NaN         NaN
# 28              NaN                                   NaN         NaN
# 29              NaN                                   NaN         NaN
# 30              NaN                                   NaN         NaN
# 31              NaN                                   NaN         NaN
# 32              NaN                                   NaN         NaN
# 33              NaN                                   NaN         NaN
# 34              NaN                                   NaN         NaN
# 35              NaN                                   NaN         NaN
# 36              NaN                                   NaN         NaN
# 37              NaN                                   NaN         NaN
# 38              NaN                                   NaN         NaN
# 39              NaN                                   NaN         NaN
# 40              NaN                                   NaN         NaN
# 41              NaN                                   NaN         NaN
# 42              NaN                                   NaN         NaN
# 43              NaN                                   NaN         NaN
# 44              NaN                                   NaN         NaN
# 45              NaN                                   NaN         NaN
# 46              NaN                                   NaN         NaN
# 47              NaN                                   NaN         NaN
# 48              NaN                                   NaN         NaN
# 49              NaN                                   NaN         NaN
