# %% [markdown]
# <a id="systematic_review"></a>
#
# <div>
#     <details>
#         <summary>
#             <h1 align="center" style="font-family:Times New Roman;font-variant:small-caps;">
#                 Systematic Review
#             </h1>
#         </summary>
#         <p>
#         </p>
#     </details>
# </div>

# %%
import ipywidgets as widgets
from IPython.display import display
from src.buttons import button

# %%
a = button("Protocol", "./3_protocol.ipynb")
b = button("Search Strategy", "./4_search_strategy.ipynb")
c = button("Search", "./5_search.ipynb")
d = button("Deduplication", "./6_deduplication.ipynb")
e = button("Screening", "./7_screening.ipynb")
# Out:
# HBox(children=(Button(description='Protocol', style=ButtonStyle()), Output()))
# HBox(children=(Button(description='Search Strategy', style=ButtonStyle()), Output()))
# HBox(children=(Button(description='Search', style=ButtonStyle()), Output()))
# HBox(children=(Button(description='Deduplication', style=ButtonStyle()), Output()))
# HBox(children=(Button(description='Screening', style=ButtonStyle()), Output()))
