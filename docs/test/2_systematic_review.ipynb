# %% [markdown]
# <a id="systematic_review"></a>
#
# <div>
#     <details>
#         <summary>
#             <h1 align="center" style="font-family:Times New Roman;font-variant:small-caps;">
#                 Systematic Review
#             </h1>
#         </summary>
#         <p>
#         </p>
#     </details>
# </div>

# %%
import ipywidgets as widgets
from IPython.display import display
from src.buttons import button

# %%
headings = {
    "Protocol": "./3_protocol.ipynb",
    "Search Strategy": "./4_search_strategy.ipynb",
    "Search": "./5_search.ipynb",
    "Deduplication": "./6_deduplication.ipynb",
    "Screening": "./7_screening.ipynb"
}

ws = []

for x, y in headings.items():
    w = button(x, y)
    ws.append(w)

wid = widgets.HBox(children = ws)
display(wid)

# %%
a = button("Protocol", "./3_protocol.ipynb")
b = button("Search Strategy", "./4_search_strategy.ipynb")
c = button("Search", "./5_search.ipynb")
d = button("Deduplication", "./6_deduplication.ipynb")
e = button("Screening", "./7_screening.ipynb")
