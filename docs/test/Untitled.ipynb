# %%
import ipywidgets as widgets
from IPython.display import display, Javascript

# %% [markdown]
# **Buttons**

# %%
button = widgets.Button(
    description="Go to search strategy",
    button_style="primary"
)

def go_to_page(b):
    display(Javascript("""
        window.location.href = "search_strategy.ipynb";
    """))

button.on_click(go_to_page)

display(button)

# %% [markdown]
# **Custom navigation buttons**: Creates a horizontal flexbox of buttons across the top section of the web page.

# %%
import ipywidgets as widgets
from IPython.display import display
import os
from pathlib import Path

# set default layouts for flexboxes, and for items, such as buttons, as in this case.
items_layout = widgets.Layout(width = "100%", border = "solid 0.5px")
box_layout = widgets.Layout(display = "flex", flex_flow = "row", align_items = "stretch", align_content = "stretch", width = "100%")

root = os.getcwd()

# mapping refers to a key:value pairing dictionary list of button labels to the page they refer to when clicking.
pages = {
    'Systematic Review': '2_systematic_review.ipynb', 
    'Protocol'         : '3_protocol.ipynb',
    'Search Strategy'  : '4_search_strategy.ipynb', 
    'Search'           : '5_search.ipynb', 
    'Deduplication'    : '6_deduplication.ipynb', 
    'Screening'        : '7_screening.ipynb'}

# %%
items_layout = widgets.Layout(width = "100%", border = "solid 0.5px")

def go_to_page(b):
    display(Javascript("""
        window.location.href = "2_systematic_review.ipynb";
    """))
    
A = widgets.Button(description = "Systematic Review", layout = items_layout)
A.on_click(go_to_page)

display(A)
# Out:
# Button(description='Systematic Review', layout=Layout(border_bottom='solid 0.5px', border_left='solid 0.5px', …

# %%
network_meta_analysis =  ['Systematic Review', 'Data Collection', 'Meta-Analysis', 'Manuscript']
systematic_review = ['Protocol', 'Search Strategy', 'Search', 'Deduplication', 'Screening']
data_collection = ['Data', 'Database', 'Forms', 'Extraction', 'Transformation']
meta_analysis = ['Effect Size Pooling', 'Subgroup Analysis', 'Meta-Regression', 'Forest Plots']
manuscript = ['Tables and Figures', 'Results', 'Methods', 'Introduction', 'Discussion', 'Abstract']

# %%
Nav(network_meta_analysis)
# Out:
# ...
# Output()

# %%
Nav(systematic_review)
# Out:
# ...
# Output()

# %%
Nav(data_collection)
# Out:
# ...
# Output()

# %%
Nav(meta_analysis)
# Out:
# ...
# Output()
