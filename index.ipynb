# %% [markdown]
# # Title / abstract screening

# %%
tab = widgets.Tab()

a = widgets.Text()
b = widgets.IntSlider()
c = widgets.Combobox(options = ["A", "B", "C", "D", "E"], value = "A")
d = widgets.Text()
e = widgets.Text()

A = widgets.HBox([a, b, c])
B = widgets.VBox([d, e])
C = widgets.Box([A, B])

from src.title_abstract_screening import form
D = form()

tab.children = [A, B, C, D] 
tab.titles = ['A', 'B', 'A and C', 'D']
display(tab)
# Out:
# ...
# HTML(value='', description='study ', layout=Layout(width='50%'))
# HTML(value='', description='subgroup', layout=Layout(width='50%'))
# HTML(value='', description='author(s) ', layout=Layout(width='90%'))
# HTML(value='', description='title ', layout=Layout(width='90%'))
# HTML(value='', description='abstract ', layout=Layout(height='300px', width='91.5%'))
# HTML(value='', description='year ', layout=Layout(width='90%'))
# HTML(value='', description='journal ', layout=Layout(width='90%'))
# HTML(value='', description='source', layout=Layout(width='50%'))
# HTML(value='', description='DOI ', layout=Layout(width='90%'))
# HTML(value='', description='URL ', layout=Layout(width='90%'))
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[14], line 16
#      12
#      13 from src.title_abstract_screening import form
#      14 D = form()
#      15
# ...

# %%
import ipywidgets as widgets
from IPython.display import display
from src.title_abstract_screening import form
D = form()
# Out:
# ...
# HTML(value='', description='study ', layout=Layout(width='50%'))
# HTML(value='', description='subgroup', layout=Layout(width='50%'))
# HTML(value='', description='author(s) ', layout=Layout(width='90%'))
# HTML(value='', description='title ', layout=Layout(width='90%'))
# HTML(value='', description='abstract ', layout=Layout(height='300px', width='91.5%'))
# HTML(value='', description='year ', layout=Layout(width='90%'))
# HTML(value='', description='journal ', layout=Layout(width='90%'))
# HTML(value='', description='source', layout=Layout(width='50%'))
# HTML(value='', description='DOI ', layout=Layout(width='90%'))
# HTML(value='', description='URL ', layout=Layout(width='90%'))

# %%
  
    yes = widgets.Button(
        value = "Yes", 
        description = "Yes", 
        icon = "check", 
        button_style = "success", 
        layout = {
            "width":"100%"})
    
    maybe = widgets.Button(
        value = "Maybe", 
        description = "Maybe", 
        icon = "", 
        button_style = "warning")
    
    no = widgets.Button(
        value = "No", 
        description = "No", 
        icon = "times", 
        button_style = "danger")
    
    save = widgets.Button(
        value = "Save", 
        description = "Save", 
        icon = "floppy-o", 
        button_style = "info")
    
    out = widgets.Output()
    
    buttons = widgets.HBox([yes, maybe, no, save])
    display(buttons, out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 yes = widgets.Button(
#       2     value = "Yes",
#       3     description = "Yes",
#       4     icon = "check",
#
# NameError: name 'widgets' is not defined

# %%
from src.ti
