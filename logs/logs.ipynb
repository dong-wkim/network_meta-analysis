# %% [markdown]
# ```mermaid
# gantt
#
# title 2026-04-15
# dateFormat HH:mm
# axisFormat %H:%M
# tickInterval 1h
#
# Get jupyter notebook working again :done, 08:00, 08:50
# Clean up and revise README.ipynb file :active, 08:50, 09:20
#
#
#
# ```
