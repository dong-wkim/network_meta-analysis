# %% [markdown]
# Load R kernel in python environment.

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# Install packages individually.

# %%
# %R install.packages("readxl")

# %%
# %R install.packages("Matrix")
# Out:
# package 'Matrix' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Danny\AppData\Local\Temp\RtmpaKKEMP\downloaded_packages
# Installing package into 'C:/Users/Danny/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# trying URL 'https://cran.mi2.ai/bin/windows/contrib/4.5/Matrix_1.7-5.zip'
# Content type 'application/zip' length 5067405 bytes (4.8 MB)
# downloaded 4.8 MB

# %%
# %R install.packages("meta")
# Out:
# package 'meta' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Danny\AppData\Local\Temp\RtmpaKKEMP\downloaded_packages
# Installing package into 'C:/Users/Danny/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# trying URL 'https://cran.mi2.ai/bin/windows/contrib/4.5/meta_8.3-0.zip'
# Content type 'application/zip' length 2752837 bytes (2.6 MB)
# downloaded 2.6 MB

# %%
# %R install.packages("metafor", install.dependencies = TRUE)

# %% [markdown]
# ```R
# packages <- c("meta", "metafor", "readxl", "Matrix")
# lapply(packages, install.packages, character.only = TRUE)
# ```

# %%
# %R library(readxl)
# Out:
# array(['readxl', 'tools', 'graphics', 'grDevices', 'utils', 'datasets',
#        'methods', 'base'], dtype='<U9')

# %%
# %R library(Matrix)
# Out:
# Error: package or namespace load failed for 'Matrix' in inDL(x, as.logical(local), as.logical(now), ...):
#  unable to load shared object 'C:/Program Files/R/R-4.5.3/library/stats/libs/x64/stats.dll':
#   LoadLibrary failure:  The specified module could not be found.
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File C:\tools\.venv\Lib\site-packages\rpy2\ipython\rmagic.py:768, in RMagics.eval(self, code)
#     767     r_expr = ri.parse(code)
# --> 768     value, visible = ri.evalr_expr_with_visible(
#     769         r_expr
#     770     )
#     771 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     772     # Otherwise next return seems to have copy of error.
#
# File C:\tools\.venv\Lib\site-packages\rpy2\rinterface\__init__.py:204, in evalr_expr_with_visible(expr, envir)
#     203 if error_occured[0]:
# ...

# %%
# %R library(metafor)

# %%
# %R library(meta)

# %%
import pandas as pd
