# %%
dashboard = FlexLayout(
    style = {"height":"300px","width":"100%","top-border":"0px"})
dashboard

# %%
from ipyflex import FlexLayout
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# **Tabs**

# %%
tab_contents = ['P0', 'P1', 'P2', 'P3', 'P4']
children = [widgets.Text(description = name) for name in tab_contents]
tab = widgets.Tab()
tab.children = children
tab.titles = [str(i) for i in range(len(children))]
tab
# Out:
#   Cell In[15], line 6
#     "id", "study", "
#                    ^
# SyntaxError: unterminated string literal (detected at line 6)

# %% [markdown]
# **Widgets**

# %% [markdown]
# **Factories**

# %%
factories = {
    "IntSlider": IntSlider(),
    "FloatSlider": FloatSlider(),
    "FloatLogSlider": FloatLogSlider(),
    "IntRangeSlider": IntRangeSlider(),
    "FloatRangeSlider": FloatRangeSlider(),
    "IntProgress": IntProgress(),
    "FloatProgress": FloatProgress(),
    "BoundedIntText": BoundedIntText(),
    "BoundedFloatText": BoundedFloatText(),
    "IntText": IntText(),
    "FloatText": FloatText(),
    "ToggleButton": ToggleButton(),
    "Checkbox": Checkbox(),
    "Valid": Valid(),
    "Dropdown": Dropdown(),
    "outcomes": outcomes(),
    "RadioButtons": RadioButtons(),
    "Select": Select(),
    "SelectionSlider": SelectionSlider(),
    "SelectionRangeSlider": SelectionRangeSlider(),
    "ToggleButtons": ToggleButtons(),
    "SelectMultiple": SelectMultiple()
}
