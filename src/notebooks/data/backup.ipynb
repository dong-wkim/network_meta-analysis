# %%
# %pip install -q ipywidgets

# %%
Slider()
# Out:
# IntSlider(value=0, step=0)
# Output()

# %% [markdown]
# 1. a = intSlider()
# 2. b = floatSlider()
# 3. c = floatLogSlider()
# 4. e = intRangeSlider()
# 5. f = floatRangeSlider()
# 6. g = intProgress()
# 7. h = floatProgress()
# 8. i = boundedIntText()
# 9. j = boundedFloatText()
# 10. k = intText()
# 11. l = floatText()
# 12. m = toggleButton()
# 13. n = checkbox()
# 14. o = valid()
# 15. p = dropdown()
# 16. q = radioButtons()
# 17. r = select()
# 18. s = selectionSlider()
# 19. t = selectionRangeSlider()
# 20. u = toggleButtons()
# 21. v = selectMultiple()

# %%
import ipywidgets as widgets
from ipyflex import FlexLayout
from IPython.display import display

def Sliders(value = (0, 100), label = "", step = 0.1 ):
    return widgets.FloatRangeSlider(
        step = step,
        value = value, 
        description = label)

a = Sliders()
display(a)
# Out:
# FloatRangeSlider(value=(0.0, 100.0))

# %%
def Slider(x = "float", label = "", value = 0, min = 0, max = 100, step = 0.1):
    return widgets.IntSlider(
        step = step,
        value = 0, 
        description = label)
    
    return widgets.FloatSlider(
        min = a, 
        max = b,
        step = step,
        value = float(value),
        description = label)

a = Slider(value = (0, 100), label = "Label", a = 0, b = 100, step = 0.1)
display(a, widgets.Output())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 14
#      10             step = step,
#      11             value = float(value),
#      12             description = label)
#      13
# ---> 14 a = Slider(value = (0, 100), label = "Label", a = 0, b = 100, step = 0.1)
#      15
#      16 display(a, widgets.Output())
#
# TypeError: Slider() got an unexpected keyword argument 'a'

# %%
   if x == "int" and y == "range":
        return widgets.IntRangeSlider(
            min = a, 
            max = b,
            step = step,
            value = int(value),
            description = label)
    if x == "float" and y == "range":  
        return widgets.FloatRangeSlider(
            min = a, 
            max = b,
            step = step,
            value = float(value), 
            description = label)

# %% [markdown]
# **progress(** x, value, label, min, max, step, color, orientation **)**

# %%
# Out:
# IntSlider(value=0, step=0)
# Output()

# %%
def progress(x = "float", value = 0, label = "", min = 0, max = 100, step = 0.1, color = "green", orientation = "horizontal"):
    if x == "int":
        return widgets.IntProgress(
            value = int(value), description = label, min = min, max = max, step = step, style={'bar_color': f"{color}"}, orientation = orientation, )

    if x == "float":
        return widgets.FloatProgress(
            value = float(value), description = label, min = min, max = max, step = step, style={'bar_color': f"{color}"}, orientation = orientation)


# progress

g = progress("float", 75, "", 0, 100, 0.01, "green", orientation = "horizontal")
h = progress("int", 25, "", 0, 100, 0.01, "red", orientation = "horizontal")

display(g, h)
# Out:
# FloatProgress(value=75.0, style=ProgressStyle(bar_color='green'))
# IntProgress(value=25, style=ProgressStyle(bar_color='red'))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 Text.keys
#
# AttributeError: 'function' object has no attribute 'keys'

# %% [markdown]
# version 2.0

# %% [markdown]
# version 1.0
#
# *i, j, k, l* = **textbox(** x, y, value, label **)**

# %%
def Text(x = "bounded", y = "float", value = 0, label = ""):
    if x == "bounded":
        if y == "int":
            return widgets.BoundedIntText(
        		value = int(value), 
                description = label,
            )

        if y == "float":
            return widgets.BoundedFloatText(
        		value = float(value), 
                description = label
            )
        
    if x == None:
        if y == "int":
            return widgets.IntText(
            value = int(value), 
            description = label
        )
            
        if y == "float":
        	return widgets.FloatText(
        		value = float(value), 
                description = label
            )

# %%
i = Text("bounded", "float", 0, "Label")
j = Text("bounded", "int", 0, "Label")
k = Text(None, "float", 0, "Label")
l = Text(None, "int", 0, "Label")

display(i, j, k, l)
# Out:
# BoundedIntText(value=0, description='Label')
# BoundedFloatText(value=0.0, description='Label')
# IntText(value=0, description='Label')
# FloatText(value=0.0, description='Label')

# %% [markdown]
# **boolean(** value, label **)**

# %%
def ToggleButton(value = 'True/False', label = 'Label', icon:'fontawesome names without fa-'):
    return widgets.ToggleButton(
        value = value,
        description = label,
        disabled=False,
        button_style='',
        tooltip='Description',
        icon = icon
    )

m = toggleButton()
display(m)

def Checkbox(value: 'True/False', label: 'Label for checkbox'):
    return widgets.Checkbox(
        value=value,
        description=label,
        disabled=False,
        indent=False
)

def Valid(value = "", label = ""):
	return widgets.Valid(
        value=value,
        description=label,
    )

def Dropdown(value = "", label = ""):
	return widgets.Dropdown(
		value = float(value), 
        description = label
    )

def RadioButtons(value = "", label = ""):
	return widgets.RadioButtons(
		value = float(value), 
        description = label
    )

def Select(value = "", label = ""):
	return widgets.Select(
		value = float(value), 
        description = label
    )

def SelectionSlider(value = "", label = ""):
	return widgets.SelectionSlider(
		value = float(value), 
        description = label
    )

def selectionRangeSlider(value = "", label = ""):
	return widgets.SelectionRangeSlider(
		value = float(value), 
        description = label
    )

def toggleButtons(value = "", label = ""):
	return widgets.ToggleButtons(
		value = float(value), 
        description = label
    )

def selectMultiple(value = "", label = ""):
	return widgets.SelectMultiple(
		value = float(value), 
        description = label
    )

a = IntSlider()
b = FloatSlider()
c = FloatLogSlider()
e = IntRangeSlider()
f = FloatRangeSlider()
g = IntProgress()
h = FloatProgress()
i = BoundedIntText()
j = BoundedFloatText()
k = IntText()
l = FloatText()
m = ToggleButton()
n = Checkbox()
o = Valid()
p = Dropdown()
q = RadioButtons()
r = Select()
s = SelectionSlider()
t = SelectionRangeSlider()
u = ToggleButtons()
v = SelectMultiple()

display(a)
display(b)
display(c)
display(e)
display(f)
display(g)
display(h)
display(i)
display(j)
display(k)
display(l)
display(m) # toggle button 
display(n) # checkbox 
display(o) # valid 
display(p) # dropdown
display(q) # radiobuttons
display(r) 
display(s)
display(t)
display(u)
display(v)
# Out:
#   Cell In[99], line 1
#     def toggleButton(value = 'True/False', label = 'Label', icon:'fontawesome names without fa-'):
#                                                             ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
from ipywidgets import AppLayout, Button, Layout

def create_expanded_button(description, button_style):
    return Button(description=description, button_style=button_style, layout=Layout(height='100%', width='100%'))

header_button = create_expanded_button('Header', 'success')
left_button = create_expanded_button('Left', 'info')
center_button = create_expanded_button('Center', 'warning')
right_button = create_expanded_button('Right', 'info')
footer_button = create_expanded_button('Footer', 'success')

AppLayout(header=header_button,
          left_sidebar=left_button,
          center=center_button,
          right_sidebar=right_button,
          footer=footer_button)
# Out:
# AppLayout(children=(Button(button_style='success', description='Header', layout=Layout(grid_area='header', hei…

# %%
tab_contents = ['P0', 'P1', 'P2', 'P3', 'P4']
children = [widgets.Text(description=name) for name in tab_contents]
tab = widgets.Tab()
tab.children = children
tab.titles = [str(i) for i in range(len(children))]
tab
# Out:
# Tab(children=(Text(value='', description='P0'), Text(value='', description='P1'), Text(value='', description='…

# %%
def selectMultiple(value: 'Initial value', options: 'List', label: 'Label for valid'):
    return widgets.SelectMultiple(
        options=options,
        value=value,
        #rows=10,
        description=label,
        disabled=False
    )
    
m = selectMultiple(value = ["IKDC-SKF", "Pivot shift"], options = ["IKDC-SKF", "Lysholm", "Tegner", "Pivot shift", "Instrumental laxity", "Lachman", "Graft rupture"], label = "Outcome(s)")
display(m)
# Out:
# SelectMultiple(description='Outcome(s)', index=(0, 3), options=('IKDC-SKF', 'Lysholm', 'Tegner', 'Pivot shift'…

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from ipyflex import FlexLayout
from IPython.display import display
from enum import Enum


tabs = { "study information": widgets.HTML("<h1>Form 1</h1>"),
          "study arms": widgets.HTML("<h1>Form 2</h1>"),
          "study results": widgets.HTML("<h1>Form 3</h1>"),
          "risk of bias": widgets.HTML("<h1>Form 4</h1>")
        }

def float_slider(label: 'Label for slider', value: 'Initial value'):
    return widgets.FloatSlider(value=float(value), description = label)

def dropdown(label: 'Label'):
    return widgets.Dropdown(options = ["ikdc subjective", "lysholm"], description = label, value = "ikdc subjective")

factories = {"Slider": float_slider,
             "Dropdown": dropdown}

dashboard = FlexLayout(tabs,
                       template = 'saved.json',
                       style = {'height': '100vh', 'borderTop': '5px'},
                       header= True,
                       layout_config = {'borderLeft': False, 'borderRight': False, 'enableSection': True},
                       editable = True,
                       factories = factories)

dashboard
# Out:
# FlexLayout(children={'study information': HTML(value='<h1>Form 1</h1>'), 'study arms': HTML(value='<h1>Form 2<…
