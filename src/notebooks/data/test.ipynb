# %%
import ipywidgets as widgets
from ipyflex import FlexLayout
from IPython.display import display

# %%
import ipywidgets as widgets
from ipyflex import FlexLayout
from IPython.display import display

def Slider(value = 0, label = "", min = 0, max = 100, step = 0.1):
    return widgets.FloatSlider(
        value = float(value), 
        description = label,
        min = min, max = max, step = step)
    
def Progress(value = 0, label = "", min = 0, max = 100, step = 0.1, color = "green", orientation = "horizontal"):
    return widgets.FloatProgress(
        value = float(value), 
        description = label, 
        min = min, max = max, step = step,
        style={'bar_color': f"{color}"}, 
        orientation = orientation)

# %%
a = Slider()
b = Progress(45, orientation = "vertical")
c = FloatText(

link = widgets.jslink((a, "value"), (b, "value"))

display(a, b)
# Out:
# FloatSlider(value=0.0)
# FloatProgress(value=45.0, orientation='vertical', style=ProgressStyle(bar_color='green'))
