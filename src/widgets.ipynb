# %% [markdown]
# Making widgets *interactive*

# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# Checklist
#
#   - [x] Create first version of forms using records.csv file and link csv $\rightarrow$ widgets
#   - [ ] Create the dataframes for the rest of the tables and connect widgets $\rightarrow$ csv
#   - [x] Yes / No / Maybe buttons for title / abstract screening
#   - [ ] Upload PDF button
#   - [ ] Included / Excluded / Reason for exclusion button

# %%
button = widgets.Button(
    description="",
    button_style="primary"
)

def go_to_page(b):
    display(Javascript("""
        window.location.href = "search_strategy.ipynb";
    """))

button.on_click(go_to_page)

display(button)
# Out:
# Button(button_style='primary', description='Go to search strategy', style=ButtonStyle())
